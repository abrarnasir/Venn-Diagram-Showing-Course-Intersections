# %%
import numpy as np
from matplotlib_venn import venn3
from matplotlib import pyplot as plt
# %matplotlib inline


eco_major = set([
    'CSC108', 'ECO101', 'ECO102', 'MAT135', 'MAT136',
    'ECO200', 'ECO202', 'ECO225', 'STA237', 'STA238',
    'ECO310', 'ECO331','ECO334', 'ECO358', 'ECO359', 'ECO372', 'ECO374',
    'ECO404', 'ECO464'
])

stat_minor = set([
    'CSC108', 'MAT135', 'MAT136',
    'MAT223', 'MAT235', 'STA237', 'STA238',
    'STA302', 'STA314'
])

math_minor = set([
    'MAT135', 'MAT136',
    'MAT223', 'MAT235', 'MAT244',
    'MAT329', 'MAT344'
])


v = venn3([eco_major, stat_minor, math_minor], ('Economics Major', 'Statistics Minor', 'Mathematics Minor'))
plt.title('Number of Courses for My Intended Programs and Their Intersections')
# Out:
# Text(0.5, 1.0, 'Number of Courses for My Intended Programs and Their Intersections')
